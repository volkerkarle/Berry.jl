# %%
using Pkg
Pkg.activate("../.")
using Berry
versioninfo()
using PyPlot
using LinearAlgebra, SparseArrays
using StaticArrays
using Distributed
using SharedArrays
println("Actual number of threads used: ", Base.Threads.nthreads())
# Out:
#   Activating project at `~/Berry.jl`
# Julia Version 1.9.0
# Commit 8e630552924 (2023-05-07 11:25 UTC)
# Platform Info:
#   OS: Linux (x86_64-linux-gnu)
#   CPU: 24 × Intel(R) Xeon(R) CPU E5-2620 v3 @ 2.40GHz
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-14.0.6 (ORCJIT, haswell)
#   Threads: 25 on 24 virtual cores
# Environment:
#   JULIA_NUM_THREADS = auto
# Actual number of threads used: 24

# %%
enum = enumerate
roll(n::Int,N::Int)  = ((n-1)%N)+1
σˣ= @SMatrix [0  1; 1  0]
σᶻ= @SMatrix [1  0; 0 -1]
σʸ= @SMatrix [0 -im;im 0]
σ    = [σˣ, σʸ, σᶻ];

# %%
# Fukui et al. 2005
function berry_curvature_2D(ψ::Array{ComplexF64,3})
    N,Nx,Ny = size(ψ)
    U_m = zeros(ComplexF64,Nx,Ny)
    U_n = zeros(ComplexF64,Nx,Ny)
    for i in 1:Nx
        for j in 1:Ny
            U_n[i,j] = ψ[:,i,j] ⋅ ψ[:,roll(i+1,Nx),j]
            U_n[i,j]/= abs(U_n[i,j])
            U_m[i,j] = ψ[:,i,j] ⋅ ψ[:,i,roll(j+1,Ny)]
            U_m[i,j]/= abs(U_m[i,j])
        end
    end
    Ω = zeros(Nx,Ny)
    for i in 1:Nx
        for j in 1:Ny
            Ω[i,j] = imag(log(U_n[i,j]*U_m[roll(i+1,Nx),j]*conj(U_n[i,roll(j+1,Ny)])*conj(U_m[i,j])))
        end
    end
    return Ω
end
# Distributed version. Somehow not faster!
function berry_curvature_2D(ψ::SharedArray{ComplexF64,3})
    println("Distributed function is used.")
    N,Nx,Ny = size(ψ)
    U_m = SharedArray{ComplexF64}(Nx,Ny)
    U_n = SharedArray{ComplexF64}(Nx,Ny)
    @distributed for i in 1:Nx
        for j in 1:Ny
            U_n[i,j] = ψ[:,i,j] ⋅ ψ[:,roll(i+1,Nx),j]
            U_n[i,j]/= abs(U_n[i,j])
            U_m[i,j] = ψ[:,i,j] ⋅ ψ[:,i,roll(j+1,Ny)]
            U_m[i,j]/= abs(U_m[i,j])
        end
    end
    Ω = SharedArray{Float64}(Nx,Ny)
    @distributed for i in 1:Nx
        for j in 1:Ny
            Ω[i,j] = imag(log(U_n[i,j]*U_m[roll(i+1,Nx),j]*conj(U_n[i,roll(j+1,Ny)])*conj(U_m[i,j])))
        end
    end
    return Ω
end
# Out:
# berry_curvature_2D (generic function with 2 methods)

# %% [markdown]
# # Spin models

# %%
function diagonalize_BHZ(Δ,Nkx=50,Nky=50)
    kx_all = LinRange(0,2π,Nkx)
    ky_all = LinRange(0,2π,Nky)
    H_BHZ(kx,ky,Δ) = sin(kx)*σˣ+ sin(ky)*σʸ+ (Δ + cos(kx)+cos(ky))*σᶻ
    E_all = SharedArray{Float64}(2,Nkx,Nky)
    ψ_all = SharedArray{ComplexF64}(2,2,Nkx,Nky)
    H = @SMatrix zeros(2,2)
    @distributed for ikx ∈ 1:Nkx
        kx = kx_all[ikx]
        for iky ∈ 1:Nky
            ky = ky_all[iky]
            H = H_BHZ(kx,ky,Δ)
            E_all[:,ikx,iky],ψ_all[:,:,ikx,iky] = eigen(H)
        end
    end
    return Array(E_all), Array(ψ_all)
end
# Out:
# diagonalize_BHZ (generic function with 3 methods)

# %%
E_all, ψ_all = diagonalize_BHZ(1.5,300,301);

# %%
@time Ω = berry_curvature_2D(ψ_all[:,1,:,:]);
C = sum(Ω)/(2π)
# Out:
#   0.296541 seconds (852.93 k allocations: 64.488 MiB, 6.87% gc time, 73.89% compilation time)
# 1.0

# %%
ψ_dist = SharedArray{ComplexF64}(ψ_all[:,1,:,:])
@time Ω = berry_curvature_2D(ψ_dist);
C = sum(Ω)/(2π)
# Out:
# Distributed function is used.
#   0.731626 seconds (688.06 k allocations: 54.573 MiB, 3.71% gc time, 91.85% compilation time)
# 1.0

# %%
Nkx=300
Nky=301
kx_all = LinRange(0,2π,Nkx)
ky_all = LinRange(0,2π,Nky)
fig, ax = plt.subplots(figsize=(3,2))
yticks,ylabels = gen_ticks(step=1//2, N=5, min=0)

ax.set_yticklabels(ylabels)
ax.set_yticks(yticks)
ax.set_xlabel(L"k_x")
ax.set_ylabel(L"k_y")

ax.set_xticklabels(ylabels)
ax.set_xticks(yticks)

im1 = ax.pcolormesh(kx_all,ky_all,Ω'/(2π),cmap="inferno")
plt.colorbar(im1)

ax.set_title(L"\int \Omega(k_x,k_y)\mathrm{d}k_x\mathrm{d}k_y = 2\pi") 

plt.show()
# Out:
# sys:1: UserWarning: FixedFormatter should only be used together with FixedLocator
# Figure(PyObject <Figure size 300x200 with 2 Axes>)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1, 3, 1, projection="3d",azim=+00,elev=20)
for ax ∈ [ax1,ax2,ax3]
    ax.scatter(n[1,:,:],n[2,:,:],n[3,:,:],s=1,alpha=0.1)
end
plt.tight_layout()
plt.show()

# %%
Δ = 3/2


Nk = 150
kx_all = LinRange(0,2π, Nk)
ky_all = LinRange(0,2π, Nk)
n = zeros(3,Nk^2) 
ii = 0
for (ikx,kx) ∈ enum(kx_all)
    for (iky, ky) ∈ enum(ky_all)
        ii += 1
        n[:,ii] = [sin(kx), sin(ky),  (Δ + cos(kx)+cos(ky))]
    end
end

# %%
fig = plt.figure()
ax = fig.add_subplot(projection="3d",azim=+30,elev=15)
ax.scatter(n[1,:],n[2,:],n[3,:],s=1,alpha=0.1)
ax.scatter([0],[0],[0])
plt.show()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
